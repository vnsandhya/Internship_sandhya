# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/loan_prediction.csv')
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.shape
# Out:
# (614, 13)

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (480, 13)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (480, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 1 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            480 non-null    object
#  1   Gender             480 non-null    object
#  2   Married            480 non-null    object
#  3   Dependents         480 non-null    object
#  4   Education          480 non-null    object
#  5   Self_Employed      480 non-null    object
#  6   ApplicantIncome    480 non-null    int64
#  7   CoapplicantIncome  480 non-null    float64
#  8   LoanAmount         480 non-null    float64
#  9   Loan_Amount_Term   480 non-null    float64
#  10  Credit_History     480 non-null    float64
#  11  Property_Area      480 non-null    object
#  12  Loan_Status        480 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 52.5+ KB

# %%
df=df.drop(columns='Loan_ID',axis=1)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 1 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             480 non-null    object
#  1   Married            480 non-null    object
#  2   Dependents         480 non-null    object
#  3   Education          480 non-null    object
#  4   Self_Employed      480 non-null    object
#  5   ApplicantIncome    480 non-null    int64
#  6   CoapplicantIncome  480 non-null    float64
#  7   LoanAmount         480 non-null    float64
#  8   Loan_Amount_Term   480 non-null    float64
#  9   Credit_History     480 non-null    float64
#  10  Property_Area      480 non-null    object
#  11  Loan_Status        480 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 48.8+ KB
# None

# %%
from sklearn.preprocessing import LabelEncoder

laen=LabelEncoder()
dff=laen.fit_transform(df['Gender'])
pd.Series(df['Gender'])
df['Gender']=dff
df.head()
# Out:
#    Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1       1     Yes          1      Graduate            No             4583
# 2       1     Yes          0      Graduate           Yes             3000
# 3       1     Yes          0  Not Graduate            No             2583
# 4       1      No          0      Graduate            No             6000
# 5       1     Yes          2      Graduate           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status
# 1         Rural           N
# 2         Urban           Y
# 3         Urban           Y
# 4         Urban           Y
# 5         Urban           Y

# %%
laen=LabelEncoder()
dff=laen.fit_transform(df['Married'])
pd.Series(df['Married'])
df['Married']=dff
df.head()
# Out:
#    Gender  Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1       1        1          1      Graduate            No             4583
# 2       1        1          0      Graduate           Yes             3000
# 3       1        1          0  Not Graduate            No             2583
# 4       1        0          0      Graduate            No             6000
# 5       1        1          2      Graduate           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status
# 1         Rural           N
# 2         Urban           Y
# 3         Urban           Y
# 4         Urban           Y
# 5         Urban           Y

# %%
laen=LabelEncoder()
dff=laen.fit_transform(df['Education'])
pd.Series(df['Education'])
df['Education']=dff
df.head()
# Out:
#    Gender  Married Dependents  Education Self_Employed  ApplicantIncome  \
# 1       1        1          1          0            No             4583
# 2       1        1          0          0           Yes             3000
# 3       1        1          0          1            No             2583
# 4       1        0          0          0            No             6000
# 5       1        1          2          0           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status
# 1         Rural           N
# 2         Urban           Y
# 3         Urban           Y
# 4         Urban           Y
# 5         Urban           Y

# %%
laen=LabelEncoder()
dff=laen.fit_transform(df['Self_Employed'])
pd.Series(df['Self_Employed'])
df['Self_Employed']=dff
df.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1       1        1          1          0              0             4583
# 2       1        1          0          0              1             3000
# 3       1        1          0          1              0             2583
# 4       1        0          0          0              0             6000
# 5       1        1          2          0              1             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status
# 1         Rural           N
# 2         Urban           Y
# 3         Urban           Y
# 4         Urban           Y
# 5         Urban           Y

# %%
laen=LabelEncoder()
dff=laen.fit_transform(df['Property_Area'])
pd.Series(df['Property_Area'])
df['Property_Area']=dff
df.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1       1        1          1          0              0             4583
# 2       1        1          0          0              1             3000
# 3       1        1          0          1              0             2583
# 4       1        0          0          0              0             6000
# 5       1        1          2          0              1             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#    Property_Area Loan_Status
# 1              0           N
# 2              2           Y
# 3              2           Y
# 4              2           Y
# 5              2           Y

# %%
laen=LabelEncoder()
dff=laen.fit_transform(df['Loan_Status'])
pd.Series(df['Loan_Status'])
df['Loan_Status']=dff
df.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1       1        1          1          0              0             4583
# 2       1        1          0          0              1             3000
# 3       1        1          0          1              0             2583
# 4       1        0          0          0              0             6000
# 5       1        1          2          0              1             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#    Property_Area  Loan_Status
# 1              0            0
# 2              2            1
# 3              2            1
# 4              2            1
# 5              2            1

# %%
laen=LabelEncoder()
dff=laen.fit_transform(df['Dependents'])
pd.Series(df['Dependents'])
df['Dependents']=dff
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1       1        1           1          0              0             4583
# 2       1        1           0          0              1             3000
# 3       1        1           0          1              0             2583
# 4       1        0           0          0              0             6000
# 5       1        1           2          0              1             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#    Property_Area  Loan_Status
# 1              0            0
# 2              2            1
# 3              2            1
# 4              2            1
# 5              2            1

# %%
df.describe()
# Out:
#            Gender     Married  Dependents   Education  Self_Employed  \
# count  480.000000  480.000000  480.000000  480.000000     480.000000
# mean     0.820833    0.647917    0.777083    0.202083       0.137500
# std      0.383892    0.478118    1.020815    0.401973       0.344734
# min      0.000000    0.000000    0.000000    0.000000       0.000000
# 25%      1.000000    0.000000    0.000000    0.000000       0.000000
# 50%      1.000000    1.000000    0.000000    0.000000       0.000000
# 75%      1.000000    1.000000    2.000000    0.000000       0.000000
# max      1.000000    1.000000    3.000000    1.000000       1.000000
#
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       480.000000         480.000000  480.000000        480.000000
# mean       5364.231250        1581.093583  144.735417        342.050000
# std        5668.251251        2617.692267   80.508164         65.212401
# min         150.000000           0.000000    9.000000         36.000000
# 25%        2898.750000           0.000000  100.000000        360.000000
# 50%        3859.000000        1084.500000  128.000000        360.000000
# 75%        5852.500000        2253.250000  170.000000        360.000000
# max       81000.000000       33837.000000  600.000000        480.000000
#
#        Credit_History  Property_Area  Loan_Status
# count      480.000000     480.000000   480.000000
# mean         0.854167       1.022917     0.691667
# std          0.353307       0.776411     0.462287
# min          0.000000       0.000000     0.000000
# 25%          1.000000       0.000000     0.000000
# 50%          1.000000       1.000000     1.000000
# 75%          1.000000       2.000000     1.000000
# max          1.000000       2.000000     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 1 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             480 non-null    int32
#  1   Married            480 non-null    int32
#  2   Dependents         480 non-null    int32
#  3   Education          480 non-null    int32
#  4   Self_Employed      480 non-null    int32
#  5   ApplicantIncome    480 non-null    int64
#  6   CoapplicantIncome  480 non-null    float64
#  7   LoanAmount         480 non-null    float64
#  8   Loan_Amount_Term   480 non-null    float64
#  9   Credit_History     480 non-null    float64
#  10  Property_Area      480 non-null    int32
#  11  Loan_Status        480 non-null    int32
# dtypes: float64(4), int32(7), int64(1)
# memory usage: 35.6 KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

plt.figure(figsize = (18,20))
plotnumber = 1
for column in df:
    if plotnumber<=11:
        ax = plt.subplot(4,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize = 20)
    plotnumber += 1
plt.tight_layout()

# %%
df_cor=df.corr().abs()  
plt.figure(figsize=(16,14))
sns.heatmap(df_cor,annot=True,cmap="Blues")
plt.show()

# %%
df['Loan_Status'].value_counts()
# Out:
# 1    332
# 0    148
# Name: Loan_Status, dtype: int64

# %%
y=df.Loan_Status
x=df.drop(columns='Loan_Status',axis=1)

# %%
import six
import joblib
import sys
sys.modules['sklearn.externals.six']=six
sys.modules['sklearn.modules.joblib']=joblib
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
over_samp=SMOTE(0.75)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,stratify =y,random_state =42)

# %%
x_train_s,y_train_s=over_samp.fit_resample(x_train,y_train)

# %%
Counter(y_train)
# Out:
# Counter({1: 266, 0: 118})

# %%
Counter(y_train_s)
# Out:
# Counter({1: 266, 0: 199})

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
clf1 = LogisticRegression(solver='liblinear')
clf1.fit(x_train_s, y_train_s)
lr_y_pred = clf1.predict(x_test)
lr_accuracy = accuracy_score(y_test,lr_y_pred)*100

print("accuracy=",lr_accuracy)
# Out:
# accuracy= 81.25

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

clf2 = tree.DecisionTreeClassifier()
clf2 = clf2.fit(x_train_s, y_train_s)
dtc_y_pred = clf2.predict(x_test)
dtc_accuracy = accuracy_score(y_test,dtc_y_pred)*100

print("accuracy=",dtc_accuracy)
# Out:
# accuracy= 77.08333333333334

# %%
from sklearn.ensemble import RandomForestClassifier

clf3 = RandomForestClassifier()
clf3.fit(x_train_s, y_train_s)
rfc_y_pred = clf1.predict(x_test)
rfc_accuracy = accuracy_score(y_test,rfc_y_pred) * 100
print("accuracy=",rfc_accuracy)
# Out:
# accuracy= 81.25

# %%
from sklearn.model_selection import GridSearchCV

paramgrid = {'max_depth': list(range(1,20,2)),'n_estimators':list(range(1,200,20))}
grid_search = GridSearchCV(RandomForestClassifier(random_state=1),paramgrid)
grid_search.fit(x_train_s,y_train_s)
grid_search.best_estimator_
# Out:
# RandomForestClassifier(max_depth=15, n_estimators=61, random_state=1)

# %%
grid_forest_model = RandomForestClassifier(random_state=1,max_depth=15,n_estimators=61)
grid_forest_model.fit(x_train_s,y_train_s)
# Out:
# RandomForestClassifier(max_depth=15, n_estimators=61, random_state=1)

# %%
pred_grid_forest = grid_forest_model.predict(x_test)
score_grid_forest = accuracy_score(pred_grid_forest,y_test)*100
score_grid_forest
# Out:
# 78.125

# %%
importances = pd.Series(clf3.feature_importances_,index=x.columns)
importances.plot(kind='barh', figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
#Accuracies of all Classifiers
print("Accuracy of Random Forest Classifier =",rfc_accuracy)
print("Accuracy of Logistic Regressor =",lr_accuracy)
print("Accuracy of Decision Tree Classifier = ",dtc_accuracy)
print("Accuracy of Grid search with Random Forest = ",score_grid_forest)
# Out:
# Accuracy of Random Forest Classifier = 81.25
# Accuracy of Logistic Regressor = 81.25
# Accuracy of Decision Tree Classifier =  77.08333333333334
# Accuracy of Grid search with Random Forest =  78.125
